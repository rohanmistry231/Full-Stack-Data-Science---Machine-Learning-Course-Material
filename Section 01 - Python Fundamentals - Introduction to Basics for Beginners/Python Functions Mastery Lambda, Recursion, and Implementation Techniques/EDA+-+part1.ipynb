# %% [markdown]
# # Task Summary
# Follwing is the EDA for a public hosted database for college soccer in US.
# https://www.kaggle.com/jeffgallini/college-football-team-stats-2019/data#

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls '/content/drive/MyDrive/Younity/Data Analysis /EDA/EDA using Pandas & Numpy/CardioGoodFitness-1.csv'
# Out:
# '/content/drive/MyDrive/Younity/Data Analysis /EDA/EDA using Pandas & Numpy/CardioGoodFitness-1.csv'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/Younity/Data Analysis /EDA/EDA using Pandas & Numpy/cfb13.csv')

# %%
df #Initial structure of the data
# Out:
#                         Team  Games  Win  Loss  Off.Rank  Off.Plays  \
# 0                Akron (MAC)     12    5     7       106        837
# 1              Alabama (SEC)     13   11     2        33        826
# 2           Arizona (Pac-12)     13    8     5        31       1030
# 3       Arizona St. (Pac-12)     14   10     4        32       1102
# 4             Arkansas (SEC)     12    3     9        99        775
# ..                       ...    ...  ...   ...       ...        ...
# 106  Washington St. (Pac-12)     13    6     7        54        999
# 107   West Virginia (Big 12)     12    4     8        62        892
# 108   Western Ky. (Sun Belt)     12    8     4        30        875
# 109      Western Mich. (MAC)     12    1    11       110        827
# 110      Wisconsin (Big Ten)     13    9     4        18        912
#
#      Off.Yards  Off.Yards.Play  Off.TDs  Total.TDs  ...  \
# 0         4104            4.90       30         31  ...
# 1         5903            7.15       58         65  ...
# 2         5960            5.79       52         57  ...
# 3         6402            5.81       64         69  ...
# 4         4286            5.53       29         30  ...
# ..         ...             ...      ...        ...  ...
# 106       5478            5.48       46         51  ...
# 107       4932            5.53       34         38  ...
# 108       5502            6.29       46         47  ...
# 109       3926            4.75       22         23  ...
# 110       6251            6.85       57         59  ...
#
#      Average.Time.of.Possession.per.Game  Turnover.Rank  Fumbles.Recovered  \
# 0                                  29:20             74                  6
# 1                                  32:00             48                  8
# 2                                  28:30             39                  4
# 3                                  30:21              7                 12
# 4                                  30:26            111                  6
# ..                                   ...            ...                ...
# 106                                28:37             93                 14
# 107                                28:19             86                 16
# 108                                32:22            112                  7
# 109                                28:42            107                 10
# 110                                33:34             56                 11
#
#      Opponents.Intercepted  Turnovers.Gain  Fumbles.Lost  \
# 0                       13              19            11
# 1                       11              19            10
# 2                       18              22            11
# 3                       21              33             6
# 4                        8              14            12
# ..                     ...             ...           ...
# 106                     16              30            11
# 107                     12              28            16
# 108                     14              21            15
# 109                      8              18             8
# 110                      9              20             4
#
#      Interceptions.Thrown.y  Turnovers.Lost  Turnover.Margin  \
# 0                        10              21               -2
# 1                         7              17                2
# 2                         7              18                4
# 3                        12              18               15
# 4                        11              23               -9
# ..                      ...             ...              ...
# 106                      24              35               -5
# 107                      16              32               -4
# 108                      16              31              -10
# 109                      18              26               -8
# 110                      15              19                1
#
#      Avg.Turnover.Margin.per.Game
# 0                           -0.17
# 1                            0.15
# 2                            0.31
# 3                            1.07
# 4                           -0.75
# ..                            ...
# 106                         -0.38
# 107                         -0.33
# 108                         -0.83
# 109                         -0.67
# 110                          0.08
#
# [111 rows x 146 columns]

# %% [markdown]
# ##### we want to have win-loss column to be segregated in win and loss columns respectively.

# %%
# describing stats of variables
df.describe().T
# Out:
#                               count        mean        std     min      25%  \
# Games                         111.0   12.693694   0.671400   12.00   12.000
# Win                           111.0    6.783784   3.347741    0.00    4.000
# Loss                          111.0    5.909910   2.801135    0.00    4.000
# Off.Rank                      111.0   64.198198  36.012326    1.00   33.500
# Off.Plays                     111.0  906.981982  90.784658  716.00  838.500
# ...                             ...         ...        ...     ...      ...
# Fumbles.Lost                  111.0    9.180180   2.994535    4.00    7.000
# Interceptions.Thrown.y        111.0   12.243243   4.163076    4.00    9.000
# Turnovers.Lost                111.0   21.423423   5.156725   10.00   18.000
# Turnover.Margin               111.0    0.873874   7.963687  -19.00   -4.500
# Avg.Turnover.Margin.per.Game  111.0    0.049640   0.621176   -1.58   -0.355
#
#                                 50%     75%      max
# Games                          13.0   13.00    14.00
# Win                             7.0    9.00    14.00
# Loss                            6.0    8.00    12.00
# Off.Rank                       67.0   95.50   123.00
# Off.Plays                     903.0  961.00  1136.00
# ...                             ...     ...      ...
# Fumbles.Lost                    9.0   11.00    18.00
# Interceptions.Thrown.y         12.0   15.00    26.00
# Turnovers.Lost                 21.0   24.00    38.00
# Turnover.Margin                 0.0    5.50    25.00
# Avg.Turnover.Margin.per.Game    0.0    0.44     1.92
#
# [143 rows x 8 columns]

# %%
df.shape  #this represents shape of the df 130 rows and 147 columns.
# Out:
# (111, 146)

# %%
df.columns # column names
# Out:
# Index(['Team', 'Games', 'Win', 'Loss', 'Off.Rank', 'Off.Plays', 'Off.Yards',
#        'Off.Yards.Play', 'Off.TDs', 'Total.TDs',
#        ...
#        'Average.Time.of.Possession.per.Game', 'Turnover.Rank',
#        'Fumbles.Recovered', 'Opponents.Intercepted', 'Turnovers.Gain',
#        'Fumbles.Lost', 'Interceptions.Thrown.y', 'Turnovers.Lost',
#        'Turnover.Margin', 'Avg.Turnover.Margin.per.Game'],
#       dtype='object', length=146)

# %%
df.info
# Out:
# <bound method DataFrame.info of                         Team  Games  Win  Loss  Off.Rank  Off.Plays  \
# 0                Akron (MAC)     12    5     7       106        837
# 1              Alabama (SEC)     13   11     2        33        826
# 2           Arizona (Pac-12)     13    8     5        31       1030
# 3       Arizona St. (Pac-12)     14   10     4        32       1102
# 4             Arkansas (SEC)     12    3     9        99        775
# ..                       ...    ...  ...   ...       ...        ...
# 106  Washington St. (Pac-12)     13    6     7        54        999
# 107   West Virginia (Big 12)     12    4     8        62        892
# 108   Western Ky. (Sun Belt)     12    8     4        30        875
# 109      Western Mich. (MAC)     12    1    11       110        827
# 110      Wisconsin (Big Ten)     13    9     4        18        912
#
#      Off.Yards  Off.Yards.Play  Off.TDs  Total.TDs  ...  \
# 0         4104            4.90       30         31  ...
# 1         5903            7.15       58         65  ...
# 2         5960            5.79       52         57  ...
# 3         6402            5.81       64         69  ...
# 4         4286            5.53       29         30  ...
# ..         ...             ...      ...        ...  ...
# 106       5478            5.48       46         51  ...
# 107       4932            5.53       34         38  ...
# 108       5502            6.29       46         47  ...
# 109       3926            4.75       22         23  ...
# 110       6251            6.85       57         59  ...
#
#      Average.Time.of.Possession.per.Game  Turnover.Rank  Fumbles.Recovered  \
# 0                                  29:20             74                  6
# 1                                  32:00             48                  8
# 2                                  28:30             39                  4
# 3                                  30:21              7                 12
# 4                                  30:26            111                  6
# ..                                   ...            ...                ...
# 106                                28:37             93                 14
# 107                                28:19             86                 16
# 108                                32:22            112                  7
# 109                                28:42            107                 10
# 110                                33:34             56                 11
#
#      Opponents.Intercepted  Turnovers.Gain  Fumbles.Lost  \
# 0                       13              19            11
# 1                       11              19            10
# 2                       18              22            11
# 3                       21              33             6
# 4                        8              14            12
# ..                     ...             ...           ...
# 106                     16              30            11
# 107                     12              28            16
# 108                     14              21            15
# 109                      8              18             8
# 110                      9              20             4
#
#      Interceptions.Thrown.y  Turnovers.Lost  Turnover.Margin  \
# 0                        10              21               -2
# 1                         7              17                2
# 2                         7              18                4
# 3                        12              18               15
# 4                        11              23               -9
# ..                      ...             ...              ...
# 106                      24              35               -5
# 107                      16              32               -4
# 108                      16              31              -10
# 109                      18              26               -8
# 110                      15              19                1
#
#      Avg.Turnover.Margin.per.Game
# 0                           -0.17
# 1                            0.15
# 2                            0.31
# 3                            1.07
# 4                           -0.75
# ..                            ...
# 106                         -0.38
# 107                         -0.33
# 108                         -0.83
# 109                         -0.67
# 110                          0.08
#
# [111 rows x 146 columns]>

# %%
df.dtypes
team = df['Team']

# %%
df[['Win']] = df[['Win']].apply(pd.to_numeric, errors='coerce')

# %%
cor = df.corr()

# %%
#Correlation with respect to Win variable and filtering out variables with less correlation.
columns = cor[cor["Win"]>0.75]['Win']
columns_list = columns.index
columns_list
# Out:
# Index(['Games', 'Win', 'Off.Yards', 'Off.Yards.Play', 'Off.TDs', 'Total.TDs',
#        'Redzone.Attempts', 'Redzone.Scores', 'Rushing.TD', 'Touchdowns', 'PAT',
#        'Total.Points', 'Points.Per.Game'],
#       dtype='object')

# %%
df1 = pd.DataFrame(df, columns=columns_list)

# %%
df2 = df1.drop('Games', axis= 1)
df2['Team'] = team

# %%
#create the correlation matrix heat map
plt.figure(figsize=(14,12))

sns.heatmap(df2.corr(),linewidths=.1,cmap="YlGnBu", annot=True)

plt.yticks(rotation=0);

# %%
#pair plots
g = sns.pairplot(df2)
